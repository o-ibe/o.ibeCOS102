# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def welcomeMessageL(name):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Employee Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {name}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Logistics Employees")
    label_2.pack()
    label_3 = tk.Label(window, text="ADENIRAN Oluwatamilore, AGBAKWURU Chiemeziem, ARNIKA Osose, CHUKWUMA Nedi, EZEONYE Makuochukwu, GIWA Moyosore,")
    label_3.pack()
    label_4 = tk.Label(window, text="NWOKOLO Chijindu, NWOTOKUBO Joesph, OKORO Derek, OSSAI Mary-Cynthia, PETER Owoede")
    label_4.pack()

def welcomeMessageAc(name):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Employee Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {name}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Accounting Employees")
    label_2.pack()
    label_3 = tk.Label(window, text="ADEWUMI Ayomide, AGBAKURU-NWOGU Chukwunonye, AKINDE Oluwatimehin, EBI Stephanie, ICHA Ayonete, IKPATI Eche,")
    label_3.pack()
    label_4 = tk.Label(window, text="OBASOGIE Daisy, OBI Samuel, OBIALOR Betha, OLOWOKERE Akorede, OLUBUADE Rasheed, OSEMEKE Daniel")
    label_4.pack()

def welcomeMessageD(name):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Employee Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {name}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Delivery Employees")
    label_2.pack()
    label_3 = tk.Label(window, text="ADOH-AJAGBE Oshim, ATELLY Daniel, AZOGU Onyekachi, BETURE Shalom, EJEDIMU Edward, ILOENYOSI Michael,")
    label_3.pack()
    label_4 = tk.Label(window, text="IYAWE Oluwadamilola, OGBONNA Boluwatife, OIGBOCHIE Mary, QUADRI Oluwafikunmi, UDE-IBE Uchenna")
    label_4.pack()

def welcomeMessageAd(name):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Employee Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {name}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="Administration Employees")
    label_2.pack()
    label_3 = tk.Label(window, text="EGBORO Jason, ELERI Otu, EZE Onyinyechi, OKOCHA-OJEAH Raphael, OKOLO Victor, UMEH Ejike")
    label_3.pack()


    # Run the Tkinter event loop
    root.mainloop()

def submit():
    name = name_entry.get()
    department = department_entry.get()

    if name == "ADENIRAN Oluwatamilore" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "ADEWUMI Ayomide" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "ADOH-AJAGBE Oshim" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "AGBAKURU-NWOGU Chukwunonye" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "AGBAKWURU Chiemeziem" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "AKINDE Oluwatimehin" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "ARNIKA Osose" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "ATELLY Daniel" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "AZOGU Onyekachi" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "BETURE Shalom" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "CHUKWUMA Nedi" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "EBI Stephanie" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "EGBORO Jason" and department == "Administration":
        welcomeMessageAd(name)
    elif name == "EJEDIMU Edward" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "ELERI Otu" and department == "Administration":
        welcomeMessageAd(name)
    elif name == "EZE Onyinyechi" and department == "Administration":
        welcomeMessageAd(name)
    elif name == "EZEONYE Makuochukwu" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "GIWA Moyosore" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "ICHA Ayonete" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "IKPATI Eche" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "ILOENYOSI Michael" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "IYAWE Oluwadamilola" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "NWOKOLO Chijindu" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "NWOTOKUBO Joseph" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "OBASOGIE Daisy" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "OBI Samuel" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "OBIALOR Betha" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "OGBONNA Boluwatife" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "OIGBOCHIE Mary" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "OKOCHA-OJEAH Raphael" and department == "Administration":
        welcomeMessageAd(name)
    elif name == "OKOLO Victor" and department == "Administration":
        welcomeMessageAd(name)
    elif name == "OKORO Derek" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "OLOWOKERE Akorede" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "OLUBUADE Rasheed" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "OSEMEKE Daniel" and department == "Accounting":
        welcomeMessageAc(name)
    elif name == "OSSAI Mary-Cynthia" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "PETER Owoede" and department == "Logistics":
        welcomeMessageL(name)
    elif name == "QUADRI Oluwafikunmi" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "UDE-IBE Uchenna" and department == "Delivery":
        welcomeMessageD(name)
    elif name == "UMEH Ejike" and department == "Administration":
        welcomeMessageAd(name)
    else:
        messagebox.showerror("Login", "Invalid name or department")

# Create main window
root = tk.Tk()
root.title("Login Form")
root.geometry("500x200")


# Create username label and entry
name_label = tk.Label(root, text="Name:")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

# Create department label and entry
department_label = tk.Label(root, text="Department:")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()

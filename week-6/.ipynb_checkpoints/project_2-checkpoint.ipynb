# %%
import tkinter as tk
from tkinter import messagebox

def dep_checker(department):
    if department.lower() == "computer science":
        comp_sci_select()
    elif department.lower() == "mass communication":
        mass_comm_select()
    else:
        messagebox.showerror("Error", "Invalid department entered")
        
def submit():
    department = department_entry.get().lower()
    jamb_score = int(jamb_score_entry.get())
    
    if department == "computer science":
        english = int(english_entry.get())
        math = int(math_entry.get())
        physics = int(physics_entry.get())
        chemistry = int(chemistry_entry.get())
        biology = int(biology_entry.get())
        
        if jamb_score >= 250 and english >= 60 and math >= 60 and physics >= 60 and chemistry >= 60 and biology >= 60:
            messagebox.showinfo("Candidate Result", "Congrats! You meet our requirements and have been admitted.")
        else:
            messagebox.showerror("Candidate Result", "Sorry but you do not meet our requirements and have not been admitted.")
    elif department == "mass communication":
        english = int(english_entry.get())
        math = int(math_entry.get())
        literature = int(literature_entry.get())
        economics = int(economics_entry.get())
        government = int(government_entry.get())
        
        if jamb_score >= 230 and english >= 60 and math >= 60 and literature >= 60 and economics >= 60 and government >= 60:
            messagebox.showinfo("Candidate Result", "Congrats! You meet our requirements and have been admitted.")
        else:
            messagebox.showerror("Candidate Result", "Sorry but you do not meet our requirements and have not been admitted.")
    else:
        messagebox.showerror("Error", "Invalid department entered")

def comp_sci_select():
    global english_entry, math_entry, physics_entry, chemistry_entry, biology_entry
    comp_sci_window = tk.Toplevel(root)
    comp_sci_window.title("Computer Science Subjects")
    comp_sci_window.geometry("500x200")

    english_label = tk.Label(comp_sci_window, text="English grade:")
    english_label.pack()
    english_entry = tk.Entry(comp_sci_window)
    english_entry.pack()

    math_label = tk.Label(comp_sci_window, text="Math grade:")
    math_label.pack()
    math_entry = tk.Entry(comp_sci_window)
    math_entry.pack()

    chemistry_label = tk.Label(comp_sci_window, text="Chemistry grade:")
    chemistry_label.pack()
    chemistry_entry = tk.Entry(comp_sci_window)
    chemistry_entry.pack()

    physics_label = tk.Label(comp_sci_window, text="Physics grade:")
    physics_label.pack()
    physics_entry = tk.Entry(comp_sci_window)
    physics_entry.pack()

    biology_label = tk.Label(comp_sci_window, text="Biology grade:")
    biology_label.pack()
    biology_entry = tk.Entry(comp_sci_window)
    biology_entry.pack()

    submit_button = tk.Button(comp_sci_window, text="Submit", command=submit)
    submit_button.pack()

def mass_comm_select():
    global english_entry, math_entry, literature_entry, economics_entry, government_entry
    mass_comm_window = tk.Toplevel(root)
    mass_comm_window.title("Mass Communication Subjects")
    mass_comm_window.geometry("500x200")

    english_label = tk.Label(mass_comm_window, text="English grade:")
    english_label.pack()
    english_entry = tk.Entry(mass_comm_window)
    english_entry.pack()

    math_label = tk.Label(mass_comm_window, text="Math grade:")
    math_label.pack()
    math_entry = tk.Entry(mass_comm_window)
    math_entry.pack()

    literature_label = tk.Label(mass_comm_window, text="Literature grade:")
    literature_label.pack()
    literature_entry = tk.Entry(mass_comm_window)
    literature_entry.pack()

    economics_label = tk.Label(mass_comm_window, text="Economics grade:")
    economics_label.pack()
    economics_entry = tk.Entry(mass_comm_window)
    economics_entry.pack()

    government_label = tk.Label(mass_comm_window, text="Government grade:")
    government_label.pack()
    government_entry = tk.Entry(mass_comm_window)
    government_entry.pack()

    submit_button = tk.Button(mass_comm_window, text="Submit", command=submit)
    submit_button.pack()

root = tk.Tk()
root.title("Candidate Details")
root.geometry("500x200")

department_label = tk.Label(root, text="Department:")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()

jamb_score_label = tk.Label(root, text="JAMB Score:")
jamb_score_label.pack()
jamb_score_entry = tk.Entry(root)
jamb_score_entry.pack()

submit_button = tk.Button(root, text="Submit", command=lambda: dep_checker(department_entry.get()))
submit_button.pack()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_35180\434634669.py", line 124, in <lambda>
#     submit_button = tk.Button(root, text="Submit", command=lambda: dep_checker(department_entry.get()))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_35180\434634669.py", line 11, in dep_checker
#     window.destroy()
#     ^^^^^^
# NameError: name 'window' is not defined
